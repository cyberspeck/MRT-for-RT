# %%
import FunctionsCustom as fun
from FunctionsCustom import Volume
import datetime
import numpy as np

# %%
pathCT = "../data_final/CT_x1/"
pathMR = "../data_final/MR_x1/"
pathCT_x4 = "../data_final/CT_x4/"
pathMR_x4 = "../data_final/MR_x4/"
pathCT_x9 = "../data_final/CT_x9/"
pathMR_x9 = "../data_final/MR_x9/"
pathCT_x16 = "../data_final/CT_x16/"
pathMR_x16 = "../data_final/MR_x16/"
pathCT_x25 = "../data_final/CT_x25/"
pathMR_x25 = "../data_final/MR_x25/"
pathCT_x100 = "../data_final/CT_x100/"
pathMR_x100 = "../data_final/MR_x100/"
idxSlice = 10

# %%
CT = Volume(path=pathCT, method="CT", info="x1", ref=idxSlice)
CT_x4 = Volume(path=pathCT_x4, method="CT", info="x4", ref=idxSlice)
CT_x9 = Volume(path=pathCT_x9, method="CT", info="x9", ref=idxSlice)
CT_x16 = Volume(path=pathCT_x16, method="CT", info="x16", ref=idxSlice)
CT_x25 = Volume(path=pathCT_x25, method="CT", info="x25", ref=idxSlice)
CT_x100 = Volume(path=pathCT_x100, method="CT", info="x100", ref=idxSlice)

MR = Volume(path=pathMR, method="MR", info="x1", ref=idxSlice)
MR_x4 = Volume(path=pathMR_x4, method="MR", info="x4", ref=idxSlice)
MR_x9 = Volume(path=pathMR_x9, method="MR", info="x9", ref=idxSlice)
MR_x16 = Volume(path=pathMR_x16, method="MR", info="x16", ref=idxSlice)
MR_x25 = Volume(path=pathMR_x25, method="MR", info="x25", ref=idxSlice)
MR_x100 = Volume(path=pathMR_x100, method="MR", info="x100", ref=idxSlice)
# Out:
# ('\n Import DICOM Files from: ', '../data_final/CT_x1/')
# Irregularities detected in slice 173
# Irregularities detected in slice 174
# Irregularities detected in slice 175
# Irregularities detected in slice 176
# Irregularities detected in slice 177
# Irregularities detected in slice 178
# Irregularities detected in slice 179
# Irregularities detected in slice 180
# Irregularities detected in slice 181
# Irregularities detected in slice 182
# Irregularities detected in slice 183
# Irregularities detected in slice 184
# Irregularities detected in slice 185
# Irregularities detected in slice 186
# Irregularities detected in slice 187
# Irregularities detected in slice 188
# Irregularities detected in slice 189
# Irregularities detected in slice 190
# Irregularities detected in slice 191
# Irregularities detected in slice 192
# Irregularities detected in slice 193
# ('\n Import DICOM Files from: ', '../data_final/CT_x4/')
# Irregularities detected in slice 173
# Irregularities detected in slice 174
# Irregularities detected in slice 175
# Irregularities detected in slice 176
# Irregularities detected in slice 177
# Irregularities detected in slice 178
# Irregularities detected in slice 179
# Irregularities detected in slice 180
# Irregularities detected in slice 181
# Irregularities detected in slice 182
# Irregularities detected in slice 183
# Irregularities detected in slice 184
# Irregularities detected in slice 185
# Irregularities detected in slice 186
# Irregularities detected in slice 187
# Irregularities detected in slice 188
# Irregularities detected in slice 189
# Irregularities detected in slice 190
# Irregularities detected in slice 191
# Irregularities detected in slice 192
# Irregularities detected in slice 193
# ('\n Import DICOM Files from: ', '../data_final/CT_x9/')
# Irregularities detected in slice 173
# Irregularities detected in slice 174
# Irregularities detected in slice 175
# Irregularities detected in slice 176
# Irregularities detected in slice 177
# Irregularities detected in slice 178
# Irregularities detected in slice 179
# Irregularities detected in slice 180
# Irregularities detected in slice 181
# Irregularities detected in slice 182
# Irregularities detected in slice 183
# Irregularities detected in slice 184
# Irregularities detected in slice 185
# Irregularities detected in slice 186
# Irregularities detected in slice 187
# Irregularities detected in slice 188
# Irregularities detected in slice 189
# Irregularities detected in slice 190
# Irregularities detected in slice 191
# Irregularities detected in slice 192
# Irregularities detected in slice 193
# ('\n Import DICOM Files from: ', '../data_final/CT_x16/')
# Irregularities detected in slice 173
# Irregularities detected in slice 174
# Irregularities detected in slice 175
# Irregularities detected in slice 176
# Irregularities detected in slice 177
# Irregularities detected in slice 178
# Irregularities detected in slice 179
# Irregularities detected in slice 180
# Irregularities detected in slice 181
# Irregularities detected in slice 182
# Irregularities detected in slice 183
# Irregularities detected in slice 184
# Irregularities detected in slice 185
# Irregularities detected in slice 186
# Irregularities detected in slice 187
# Irregularities detected in slice 188
# Irregularities detected in slice 189
# Irregularities detected in slice 190
# Irregularities detected in slice 191
# Irregularities detected in slice 192
# Irregularities detected in slice 193
# ('\n Import DICOM Files from: ', '../data_final/CT_x25/')
# Irregularities detected in slice 173
# Irregularities detected in slice 174
# Irregularities detected in slice 175
# Irregularities detected in slice 176
# Irregularities detected in slice 177
# Irregularities detected in slice 178
# Irregularities detected in slice 179
# Irregularities detected in slice 180
# Irregularities detected in slice 181
# Irregularities detected in slice 182
# Irregularities detected in slice 183
# Irregularities detected in slice 184
# Irregularities detected in slice 185
# Irregularities detected in slice 186
# Irregularities detected in slice 187
# Irregularities detected in slice 188
# Irregularities detected in slice 189
# Irregularities detected in slice 190
# Irregularities detected in slice 191
# Irregularities detected in slice 192
# Irregularities detected in slice 193
# ('\n Import DICOM Files from: ', '../data_final/CT_x100/')
# Irregularities detected in slice 173
# Irregularities detected in slice 174
# Irregularities detected in slice 175
# Irregularities detected in slice 176
# Irregularities detected in slice 177
# Irregularities detected in slice 178
# Irregularities detected in slice 179
# Irregularities detected in slice 180
# Irregularities detected in slice 181
# Irregularities detected in slice 182
# Irregularities detected in slice 183
# Irregularities detected in slice 184
# Irregularities detected in slice 185
# Irregularities detected in slice 186
# Irregularities detected in slice 187
# Irregularities detected in slice 188
# Irregularities detected in slice 189
# Irregularities detected in slice 190
# Irregularities detected in slice 191
# Irregularities detected in slice 192
# Irregularities detected in slice 193
# ('\n Import DICOM Files from: ', '../data_final/MR_x1/')
# ('\n Import DICOM Files from: ', '../data_final/MR_x4/')
# ('\n Import DICOM Files from: ', '../data_final/MR_x9/')
# ('\n Import DICOM Files from: ', '../data_final/MR_x16/')
# ('\n Import DICOM Files from: ', '../data_final/MR_x25/')
# ('\n Import DICOM Files from: ', '../data_final/MR_x100/')

# %%
vol_list = [[CT, CT_x4, CT_x9, CT_x16, CT_x25, CT_x100],[MR, MR_x4, MR_x9, MR_x16, MR_x25, MR_x100]]

for volumes in vol_list:
    for vol in volumes:
        #vol.getCentroid(percentLimit='auto', iterations=10)
        vol.getCentroid(threshold='auto')
        vol.showCentroid()
        vol.getMask()
        vol.getDice()
# Out:
# number of pixels (pn): 52.7071785333
#  lower: -430.61
#  upper: 333.0
# max dice-coefficient obtained for CT when compared to circle with radius = 4.125
# max dice-coefficient average for the whole volume is: 0.867115042538
# number of pixels (pn): 210.828714133
#  lower: -433.0
#  upper: 332.0
# max dice-coefficient obtained for CT when compared to circle with radius = 4.125
# max dice-coefficient average for the whole volume is: 0.945341988807
# number of pixels (pn): 474.364577847
#  lower: -444.68
#  upper: 332.0
# max dice-coefficient obtained for CT when compared to circle with radius = 4.0
# max dice-coefficient average for the whole volume is: 0.973709795561
# number of pixels (pn): 843.314856533
#  lower: -456.84
#  upper: 330.0
# max dice-coefficient obtained for CT when compared to circle with radius = 4.0
# max dice-coefficient average for the whole volume is: 0.973246497932
# number of pixels (pn): 1317.67946333
#  lower: -457.88
#  upper: 331.0
# max dice-coefficient obtained for CT when compared to circle with radius = 4.0
# max dice-coefficient average for the whole volume is: 0.977142853898
# number of pixels (pn): 5270.71785333
#  lower: -457.4
#  upper: 329.0
# max dice-coefficient obtained for CT when compared to circle with radius = 4.0
# max dice-coefficient average for the whole volume is: 0.989978976292
# number of pixels (pn): 13.1767946333
#  lower: 630.99
#  upper: 2079.0
# max dice-coefficient obtained for MR when compared to circle with radius = 2.25
# max dice-coefficient average for the whole volume is: 0.751038210042
# number of pixels (pn): 52.7071785333
#  lower: 684.2
#  upper: 2078.0
# max dice-coefficient obtained for MR when compared to circle with radius = 2.25
# max dice-coefficient average for the whole volume is: 0.870738134443
# number of pixels (pn): 118.591144462
#  lower: 690.36
#  upper: 2078.0
# max dice-coefficient obtained for MR when compared to circle with radius = 2.125
# max dice-coefficient average for the whole volume is: 0.901612864937
# number of pixels (pn): 210.828714133
#  lower: 706.05
#  upper: 2082.0
# max dice-coefficient obtained for MR when compared to circle with radius = 2.125
# max dice-coefficient average for the whole volume is: 0.907761173522
# number of pixels (pn): 329.419865833
#  lower: 705.15
#  upper: 2087.0
# max dice-coefficient obtained for MR when compared to circle with radius = 2.125
# max dice-coefficient average for the whole volume is: 0.91364198888
# number of pixels (pn): 1317.67946333
#  lower: 707.85
#  upper: 2095.0
# max dice-coefficient obtained for MR when compared to circle with radius = 2.125
# max dice-coefficient average for the whole volume is: 0.92406302941

# %%
sliceNumbers = np.arange(CT.zSize, dtype=int)
(methods, sets) = np.shape(vol_list)
distortion = np.zeros((sets, CT.zSize, 2))
distortionNorm = np.zeros((sets, CT.zSize, 1))
dice_CT_MR = np.zeros((sets, CT.zSize, 2))
for index in range(sets):
    # this calculates the coordinate difference of MR.centroid relative to CT.centroid
    distortion[index] = fun.coordShift(vol_list[0][index].centroid, vol_list[1][index].centroid)
    # this calculates the norm (=absolute distance) between the centroids in each slice
    distortionNorm[index] = fun.coordDist(distortion[index])
    # collects dice-score of CT and MRI data
    dice_CT_MR[index] = np.column_stack((vol_list[0][index].dice, vol_list[1][index].dice))

# %%
now = datetime.datetime.now()
NAMES  = ['sliceNumber', 'distortionX', 'distortionY', 'distortionNorm', 'dice_CT', 'dice_MR']
for index in range(sets):
    DATA = np.column_stack((sliceNumbers.astype(str), distortion[index].astype(str), distortionNorm[index].astype(str), dice_CT_MR[index,:,0].astype(str), dice_CT_MR[index,:,1].astype(str)))
    text = np.row_stack((NAMES, DATA))
    head0 = "{}_{}\n path: {}\n thresholds: {}, {}\n".format(vol_list[0][index].method, vol_list[0][index].info, vol_list[0][index].path, vol_list[0][index].lower, vol_list[0][index].upper)
    head1 = "{}_{}\n path: {}\n thresholds: {}, {}\n".format(vol_list[1][index].method, vol_list[1][index].info, vol_list[1][index].path, vol_list[1][index].lower, vol_list[1][index].upper)
    head = str(now) + '\n'+ head0 + head1
    np.savetxt('CT-MR_{}_{}_{}.txt'.format(vol_list[0][index].info, now.date(), now.time()), text, delimiter="   ", header=head, comments="# ", fmt='%3s')
